# %% [markdown]
# ## Introduction to Data Science
#
# #### University of Redlands - DATA 101
# #### Prof: Joanna Bieri [joanna_bieri@redlands.edu](mailto:joanna_bieri@redlands.edu)
# #### [Class Website: data101.joannabieri.com](https://joannabieri.com/data101.html)
#
# ---------------------------------------
# # Homework Day 7
# ---------------------------------------
#
# GOALS:
#
# 1. Answer all the questions from the lecture - we will use the scientists data and the grocery data.
# 2. Analyze data about College majors - your first EDA! (Think of this as a practice exam.)
#
# ----------------------------------------------------------
#
# This homework has **9 Questions** and **A Practice Exam**
#
# NOTE:
# The practice exam is intended to give you an idea of what an exam in this class might feel like. Remember you will be expected to work on the exam **independently** and submit your work before we get together to work on the exam in class. **15\% of your Exam grade will come from what you can do independently** so start practicing now and get help if you need it!.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.defaule = 'colab'

from itables import show

# %% [markdown]
# ## Lecture Questions
#
# First we will import the data about female scientists.

# %%
file1 = 'https://joannabieri.com/introdatascience/data/dates.csv'
DF_dates = pd.read_csv(file1)
file2 = 'https://joannabieri.com/introdatascience/data/professions.csv'
DF_professions = pd.read_csv(file2)
file3 = 'https://joannabieri.com/introdatascience/data/works.csv'
DF_works = pd.read_csv(file3)
show(DF_dates)
show(DF_professions)
show(DF_works)
# Out:
# <table id="itables_e6870d75_62a4_4af5_93c2_05f92705f55f" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>name</th>
#       <th>birth_year</th>
#       <th>death_year</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.5 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.12/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.12/dt_bundle.js';
#
#     document.querySelectorAll("#itables_e6870d75_62a4_4af5_93c2_05f92705f55f:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["Janaki Ammal", 1897, 1984.0], ["Chien-Shiung Wu", 1912, 1997.0], ["Katherine Johnson", 1918, 2020.0], ["Rosalind Franklin", 1920, 1958.0], ["Vera Rubin", 1928, 2016.0], ["Gladys West", 1930, NaN], ["Flossie Wong-Staal", 1947, NaN], ["Jennifer Doudna", 1964, NaN]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": []};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>
# <table id="itables_1e89c717_9e56_4296_bb85_a73b27aa20a0" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>name</th>
#       <th>profession</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.5 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.12/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.12/dt_bundle.js';
#
#     document.querySelectorAll("#itables_1e89c717_9e56_4296_bb85_a73b27aa20a0:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["Ada Lovelace", "Mathematician"], ["Marie Curie", "Physicist and Chemist"], ["Janaki Ammal", "Botanist"], ["Chien-Shiung Wu", "Physicist"], ["Katherine Johnson", "Mathematician"], ["Rosalind Franklin", "Chemist"], ["Vera Rubin", "Astronomer"], ["Gladys West", "Mathematician"], ["Flossie Wong-Staal", "Virologist and Molecular Biologist"], ["Jennifer Doudna", "Biochemist"]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": []};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>
# <table id="itables_a5147302_f757_4e5e_af47_64f0717174bc" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>name</th>
#       <th>known_for</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.5 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.12/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.12/dt_bundle.js';
#
#     document.querySelectorAll("#itables_a5147302_f757_4e5e_af47_64f0717174bc:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["Ada Lovelace", "first computer algorithm"], ["Marie Curie", "theory of radioactivity,  discovery of elements polonium and radium, first woman to win a Nobel Prize"], ["Janaki Ammal", "hybrid species, biodiversity protection"], ["Chien-Shiung Wu", "confim and refine theory of radioactive beta decy, Wu experiment overturning theory of parity"], ["Katherine Johnson", "calculations of orbital mechanics critical to sending the first Americans into space"], ["Vera Rubin", "existence of dark matter"], ["Gladys West", "mathematical modeling of the shape of the Earth which served as the foundation of GPS technology"], ["Flossie Wong-Staal", "first scientist to clone HIV and create a map of its genes which led to a test for the virus"], ["Jennifer Doudna", "one of the primary developers of CRISPR, a ground-breaking technology for editing genomes"]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": []};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %% [markdown]
# **Q1** Are each of these data sets Tidy?
#
# **Q2** Do they all contain the same number of observations?
#
# **Q3** What are the five variables?
#
# **Q4** What variable do they have in common - what can we join **on**

# %% [markdown]
# Q1: yes each of the data sets are tidy.
# Q2: no, each data set contains different amounts of observations
# Q3: These five variables are name, birth_year, death_year, known_for, and profession.
# Q4: All of the variable are refering to people, each data set shares the variable name.

# %% [markdown]
# ## Combining Three Data Sets
#
# You need to think about the order and whether or not you want to keep the maximum number of names or only keep names that are in all the data frames.
#
# In this case we will try to keep the maximal amount of data - the maximum number of names.
#
# 1. Combine the professions and works data
# 2. Then add the dates data

# %%
# 1. Combine the professions and works data
DF_scientists = pd.merge(DF_professions,DF_works,on='name',how='outer')
DF_scientists
# 2. Then add the dates data
DF_scientists = pd.merge(DF_scientists,DF_dates,on='name',how='outer')
DF_scientists
# Out:
#                  name                          profession  \
# 0        Ada Lovelace                       Mathematician
# 1     Chien-Shiung Wu                           Physicist
# 2  Flossie Wong-Staal  Virologist and Molecular Biologist
# 3         Gladys West                       Mathematician
# 4        Janaki Ammal                            Botanist
# 5     Jennifer Doudna                          Biochemist
# 6   Katherine Johnson                       Mathematician
# 7         Marie Curie               Physicist and Chemist
# 8   Rosalind Franklin                             Chemist
# 9          Vera Rubin                          Astronomer
#
#                                            known_for  birth_year  death_year
# 0                           first computer algorithm         NaN         NaN
# 1  confim and refine theory of radioactive beta d...      1912.0      1997.0
# 2  first scientist to clone HIV and create a map ...      1947.0         NaN
# 3  mathematical modeling of the shape of the Eart...      1930.0         NaN
# 4            hybrid species, biodiversity protection      1897.0      1984.0
# 5  one of the primary developers of CRISPR, a gro...      1964.0         NaN
# 6  calculations of orbital mechanics critical to ...      1918.0      2020.0
# 7  theory of radioactivity,  discovery of element...         NaN         NaN
# 8                                                NaN      1920.0      1958.0
# 9                           existence of dark matter      1928.0      2016.0

# %% [markdown]
# **Q5** What, if anything, would change if you switched to how='right'?

# %% [markdown]
# There are two more name variables.

# %% [markdown]
# ## Combining Two Data Sets - You Try
#
# **Q6** Write code that would combine the professions data and the dates data, but drop any names that don't appear in both.

# %%
# Your code here
Df_pw = pd.merge (DF_dates,DF_professions,on="name",how ="left")
Df_pw
# Out:
#                  name  birth_year  death_year  \
# 0        Janaki Ammal        1897      1984.0
# 1     Chien-Shiung Wu        1912      1997.0
# 2   Katherine Johnson        1918      2020.0
# 3   Rosalind Franklin        1920      1958.0
# 4          Vera Rubin        1928      2016.0
# 5         Gladys West        1930         NaN
# 6  Flossie Wong-Staal        1947         NaN
# 7     Jennifer Doudna        1964         NaN
#
#                            profession
# 0                            Botanist
# 1                           Physicist
# 2                       Mathematician
# 3                             Chemist
# 4                          Astronomer
# 5                       Mathematician
# 6  Virologist and Molecular Biologist
# 7                          Biochemist

# %% [markdown]
# ## Combining Three Data Sets - You Try
#
# **Q7** Try to combine the three data sets together (professions, works, and dates) but instead of doing what we did above, see if you can keep only the names that appeared in all three data sets.

# %%
# Your code here
DF_scientists = pd.merge(DF_scientists,DF_dates,on='name',how='inner')
DF_scientists
# Out:
#                  name                          profession  \
# 0     Chien-Shiung Wu                           Physicist
# 1  Flossie Wong-Staal  Virologist and Molecular Biologist
# 2         Gladys West                       Mathematician
# 3        Janaki Ammal                            Botanist
# 4     Jennifer Doudna                          Biochemist
# 5   Katherine Johnson                       Mathematician
# 6   Rosalind Franklin                             Chemist
# 7          Vera Rubin                          Astronomer
#
#                                            known_for  birth_year_x  \
# 0  confim and refine theory of radioactive beta d...        1912.0
# 1  first scientist to clone HIV and create a map ...        1947.0
# 2  mathematical modeling of the shape of the Eart...        1930.0
# 3            hybrid species, biodiversity protection        1897.0
# 4  one of the primary developers of CRISPR, a gro...        1964.0
# 5  calculations of orbital mechanics critical to ...        1918.0
# 6                                                NaN        1920.0
# 7                           existence of dark matter        1928.0
#
#    death_year_x  birth_year_y  death_year_y
# 0        1997.0          1912        1997.0
# 1           NaN          1947           NaN
# 2           NaN          1930           NaN
# 3        1984.0          1897        1984.0
# 4           NaN          1964           NaN
# 5        2020.0          1918        2020.0
# 6        1958.0          1920        1958.0
# 7        2016.0          1928        2016.0

# %% [markdown]
# ## Case study - Grocery Sales
#
# Below you will load some data about grocery sales and see how joining or merging data can help us answer questions.

# %%
file1 = 'https://joannabieri.com/introdatascience/data/purchases.csv'
DF_purchases = pd.read_csv(file1)
file2 = 'https://joannabieri.com/introdatascience/data/prices.csv'
DF_prices = pd.read_csv(file2)
show(DF_purchases)
show(DF_prices)
# Out:
# <table id="itables_92672345_1def_4278_99aa_3be791dae6f8" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>customer_id</th>
#       <th>item</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.5 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.12/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.12/dt_bundle.js';
#
#     document.querySelectorAll("#itables_92672345_1def_4278_99aa_3be791dae6f8:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [[1, "bread"], [1, "milk"], [1, "banana"], [2, "milk"], [2, "toilet paper"]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": []};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>
# <table id="itables_602866d8_8b12_417f_a7ea_7807f9fae1fb" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>item</th>
#       <th>price</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.5 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.12/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.12/dt_bundle.js';
#
#     document.querySelectorAll("#itables_602866d8_8b12_417f_a7ea_7807f9fae1fb:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["avocado", 0.5], ["banana", 0.15], ["bread", 1.0], ["milk", 0.8], ["toilet paper", 3.0]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": []};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %% [markdown]
# ## Calculate the total revenue
#
# **Q8** Given the data above find the total revenue.
#
# We will have to join the data frames so that we can see the price of what was sold. So first we look for a common column. In this case both data frames have **item** as a column.
#
# Now, think about how to calculate revenue... we need to add up the total money we made, so we need to know the price of each thing sold.
#
# **PAUSE - see if you can write some of the code for this before looking at the cells below**

# %%
#We will have to join the data frames so that we can see the price of what was sold. So first we look for a common column. 
#In this case both data frames have item as a column.
DF_revenue = pd.merge(DF_purchases, DF_prices,on='item',how='inner')
DF_revenue
# Out:
#    customer_id          item  price
# 0            1         bread   1.00
# 1            1          milk   0.80
# 2            1        banana   0.15
# 3            2          milk   0.80
# 4            2  toilet paper   3.00

# %%
#Now, think about how to calculate revenue...
#we need to add up the total money we made, 
#so we need to know the price of each thing sold.
DF_revenue['price'].sum()
# Out:
# 5.75

# %% [markdown]
# **See the lecture notes if you need heelp figuring this out!**
#
# **Q9** Calculate the revenue per customer? Hint - group by the customer id and then apply the sum().

# %%
#Calculate the revenue per customer? 
#Hint - group by the customer id and then apply the sum().
DF_cid = pd.merge(DF_purchases,DF_prices,on='item',how='inner')

# %% [markdown]
# # Practice Exam - EDA - College Majors
#
# Your solutions should include code written to answer the questions AND words describing the results. For each problem:
#
# 1. Write code to get the answers. It is okay to copy and paste from our lecture notes or your homework assignments.
# 2. Describe what the code output is telling you.
# 3. Explain any interesting aspects of your results.
#
# ------------------------
# -------------------------

# %% [markdown]
# The first step in the process of turning information into knowledge process is to summarize and describe the raw information - the data.
# In this assignment we explore data on college majors and earnings, specifically the data begin the FiveThirtyEight story ["The Economic Guide To Picking A College Major"](https://fivethirtyeight.com/features/the-economic-guide-to-picking-a-college-major/).
#
# These data originally come from the American Community Survey (ACS) 2010-2012 Public Use Microdata Series.
# While this is outside the scope of this assignment, if you are curious about how raw data from the ACS were cleaned and prepared, see [the code](https://github.com/fivethirtyeight/data/blob/master/college-majors/college-majors-rscript.R) FiveThirtyEight authors used.
#
# We should also note that there are many considerations that go into picking a major.
# Earnings potential and employment prospects are two of them, and they are important, but they don't tell the whole story.
# Keep this in mind as you analyze the data.

# %%
file_location = 'https://joannabieri.com/introdatascience/data/recent-grads.csv'
DF_raw = pd.read_csv(file_location)

# %%
DF_raw
# Out:
#      Rank  Major_code                                      Major    Total  \
# 0       1        2419                      PETROLEUM ENGINEERING   2339.0
# 1       2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2       3        2415                  METALLURGICAL ENGINEERING    856.0
# 3       4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4       5        2405                       CHEMICAL ENGINEERING  32260.0
# ..    ...         ...                                        ...      ...
# 168   169        3609                                    ZOOLOGY   8409.0
# 169   170        5201                     EDUCATIONAL PSYCHOLOGY   2854.0
# 170   171        5202                        CLINICAL PSYCHOLOGY   2838.0
# 171   172        5203                      COUNSELING PSYCHOLOGY   4626.0
# 172   173        3501                            LIBRARY SCIENCE   1098.0
#
#          Men    Women            Major_category  ShareWomen  Sample_size  \
# 0     2057.0    282.0               Engineering    0.120564           36
# 1      679.0     77.0               Engineering    0.101852            7
# 2      725.0    131.0               Engineering    0.153037            3
# 3     1123.0    135.0               Engineering    0.107313           16
# 4    21239.0  11021.0               Engineering    0.341631          289
# ..       ...      ...                       ...         ...          ...
# 168   3050.0   5359.0    Biology & Life Science    0.637293           47
# 169    522.0   2332.0  Psychology & Social Work    0.817099            7
# 170    568.0   2270.0  Psychology & Social Work    0.799859           13
# 171    931.0   3695.0  Psychology & Social Work    0.798746           21
# 172    134.0    964.0                 Education    0.877960            2
#
#      Employed  ...  Part_time  Full_time_year_round  Unemployed  \
# 0        1976  ...        270                  1207          37
# 1         640  ...        170                   388          85
# 2         648  ...        133                   340          16
# 3         758  ...        150                   692          40
# 4       25694  ...       5180                 16697        1672
# ..        ...  ...        ...                   ...         ...
# 168      6259  ...       2190                  3602         304
# 169      2125  ...        572                  1211         148
# 170      2101  ...        648                  1293         368
# 171      3777  ...        965                  2738         214
# 172       742  ...        237                   410          87
#
#      Unemployment_rate  Median  P25th   P75th  College_jobs  Non_college_jobs  \
# 0             0.018381  110000  95000  125000          1534               364
# 1             0.117241   75000  55000   90000           350               257
# 2             0.024096   73000  50000  105000           456               176
# 3             0.050125   70000  43000   80000           529               102
# 4             0.061098   65000  50000   75000         18314              4440
# ..                 ...     ...    ...     ...           ...               ...
# 168           0.046320   26000  20000   39000          2771              2947
# 169           0.065112   25000  24000   34000          1488               615
# 170           0.149048   25000  25000   40000           986               870
# 171           0.053621   23400  19200   26000          2403              1245
# 172           0.104946   22000  20000   22000           288               338
#
#      Low_wage_jobs
# 0              193
# 1               50
# 2                0
# 3                0
# 4              972
# ..             ...
# 168            743
# 169             82
# 170            622
# 171            308
# 172            192
#
# [173 rows x 21 columns]

# %% [markdown]
# ### 1. Describe the data that you see here.
#
# * How many variables?
# * How man observations?
# * Are the variables categorical or numerical?
# * Are there any variables that you don't know what they mean? If so [CLICK HERE - to see the Git Repo for the data where the variables are defined](https://github.com/fivethirtyeight/data/tree/master/college-majors)

# %%
#
DF_raw.shape
# Out:
# (173, 21)

# %% [markdown]
# this data set has 173 observations and 21 variables.

# %% [markdown]
# the variables are a mix of numerical and categorical data. Major and Major_category are both categorical data while the rest is numerical.

# %% [markdown]
# **(Click Here to Explain your Results)**

# %% [markdown]
# ### 2. Answer some questions about the data
#
# * Which major has the lowest unemployment rate? Show a data frame that answers this question, but only show columns that are useful to the answer.
# * Which major has the highest percentage of women? Show a data frame that answers this question, but only show columns that are useful to the answer.
# * How do the distributions of median income compare across major categories?
#     * First get a value count on what major categories are in the data. What categories are most or least represented?
#     * Do some summary statistics using the .group_by() command to see the statistics for each major category.
#     * Make a histogram that explores median income for each of the major categories (facet_col). How did you choose your number of bins?
#     * Why do we often choose the median, rather than the mean, to describe the typical income of a group of people? Look this up online if you don't know the answer!
#     * Answer the question: Which major category has the highest typical (you'll need to decide what this means) median income?

# %%
DF_raw.columns
# Out:
# Index(['Rank', 'Major_code', 'Major', 'Total', 'Men', 'Women',
#        'Major_category', 'ShareWomen', 'Sample_size', 'Employed', 'Full_time',
#        'Part_time', 'Full_time_year_round', 'Unemployed', 'Unemployment_rate',
#        'Median', 'P25th', 'P75th', 'College_jobs', 'Non_college_jobs',
#        'Low_wage_jobs'],
#       dtype='object')

# %%
#Which major has the lowest unemployment rate? Show a data frame that answers this question, 
#but only show columns that are useful to the answer.
my_columns = ["Unemployment_rate", "Major"]
DF_raw[my_columns].sort_values("Unemployment_rate")

mask = DF_raw["Unemployment_rate"] >0
DF_new = DF_raw[mask]
DF_new[my_columns].sort_values("Unemployment_rate")
# Out:
#      Unemployment_rate                                       Major
# 14            0.006334   ENGINEERING MECHANICS PHYSICS AND SCIENCE
# 19            0.011690                             COURT REPORTING
# 119           0.016203               MATHEMATICS TEACHER EDUCATION
# 0             0.018381                       PETROLEUM ENGINEERING
# 64            0.019642                         GENERAL AGRICULTURE
# ..                 ...                                         ...
# 29            0.128426                               PUBLIC POLICY
# 170           0.149048                         CLINICAL PSYCHOLOGY
# 84            0.151850  COMPUTER NETWORKING AND TELECOMMUNICATIONS
# 89            0.159491                       PUBLIC ADMINISTRATION
# 5             0.177226                         NUCLEAR ENGINEERING
#
# [168 rows x 2 columns]

# %% [markdown]
# The major with the lowest unemployment rate is ENGINEERING MECHANICS PHYSICS AND SCIENCE.

# %%
#Do some summary statistics using the .group_by() 
#command to see the statistics for each major category.
some_cols = ['Rank','Total', 'Men', 'Women' , 'Major_category']
DF_raw[some_cols].groupby('Major_category').max()
# Out:
#                                      Rank     Total       Men     Women
# Major_category
# Agriculture & Natural Resources       162   21573.0    9658.0   16226.0
# Arts                                  167  103480.0   32041.0   71439.0
# Biology & Life Science                169  280709.0  111762.0  168947.0
# Business                              128  329927.0  173809.0  156118.0
# Communications & Journalism           126  213996.0   70619.0  143377.0
# Computers & Mathematics               106  128319.0   99743.0   32441.0
# Education                             173  170862.0   26893.0  157833.0
# Engineering                            67   91227.0   80320.0   20957.0
# Health                                164  209394.0   21773.0  187621.0
# Humanities & Liberal Arts             168  194673.0   78253.0  136446.0
# Industrial Arts & Consumer Services   161  125074.0   62181.0   62893.0
# Interdisciplinary                     110   12296.0    2817.0    9479.0
# Law & Public Policy                    95  152824.0   80231.0   72593.0
# Physical Sciences                     111   66530.0   32923.0   35037.0
# Psychology & Social Work              172  393735.0   86648.0  307087.0
# Social Science                        143  182621.0   93880.0   88741.0

# %%
#  Make a histogram that explores median income for each of the major categories (facet_col). 
#  How did you choose your number of bins?

fig = px.histogram(DF_raw, 
                  x = 'Median',
                   nbins= 20,
                  facet_col= 'Major_category',
                  facet_col_wrap= 3,)
fig.update_layout(autosize= False,
                 width=800,
                 height=1600,)
                    

fig.show()

# %%
#Answer the question: Which major category has the highest typical 
#(you'll need to decide what this means) median income?

my_columns=['Major_category','Median','Total']
DF_raw[my_columns].groupby('Major_category').mean()
# Out:
#                                            Median          Total
# Major_category
# Agriculture & Natural Resources      36900.000000    8402.222222
# Arts                                 33062.500000   44641.250000
# Biology & Life Science               36421.428571   32418.714286
# Business                             43538.461538  100182.769231
# Communications & Journalism          34500.000000   98150.250000
# Computers & Mathematics              42745.454545   27182.545455
# Education                            32350.000000   34945.562500
# Engineering                          57382.758621   18537.344828
# Health                               36825.000000   38602.500000
# Humanities & Liberal Arts            31913.333333   47564.533333
# Industrial Arts & Consumer Services  36342.857143   32827.428571
# Interdisciplinary                    35000.000000   12296.000000
# Law & Public Policy                  42200.000000   35821.400000
# Physical Sciences                    41890.000000   18547.900000
# Psychology & Social Work             30100.000000   53445.222222
# Social Science                       37344.444444   58885.111111

# %% [markdown]
# **(Click Here to Explain your Results)**

# %% [markdown]
# ### 3. More complicated questions
#
# * Are all STEM fields the same in terms job opportunities?
#     * Assume the following are STEM major categories
#
#   ``` ["Biology & Life Science", "Computers & Mathematics", "Engineering","Physical Sciences"]```
#
#     * Create a DataFrame (using a mask) so you only look at STEM majors.
#     * Which STEM majors have median salaries equal to or less than the median for all majors' median earnings?
# * What types of majors do women tend to major in?
#     * Create a scatterplot of median income vs. proportion of women in that major, coloured by whether the major is in a STEM field or not.

# %%
#
mask = (DF_raw['Major_category']=="Biology & Life Science")|(DF_raw['Major_category']=="Computers & Mathematics")|(DF_raw['Major_category']=="Computers & Mathematics")|(DF_raw['Major_category']=="Engineering")|(DF_raw['Major_category']=="Physical Sciences")
DF_stem=DF_raw[mask]
show(DF_stem)
# Out:
# <table id="itables_97d95cf2_8468_40df_9a3e_96bbd189be67" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>
CIENCE", 4279.0, 2949.0, 1330.0, "Engineering", 0.31082, 22, 3307, 2751, 878, 1967, 78, 0.023043, 60000, 39000, 65000, 2626, 391, 81], [14, 15, 2409, "ENGINEERING MECHANICS PHYSICS AND SCIENCE", 4321.0, 3526.0, 795.0, "Engineering", 0.183985, 30, 3608, 2999, 811, 2004, 23, 0.006334, 58000, 25000, 74000, 2439, 947, 263], [15, 16, 2402, "BIOLOGICAL ENGINEERING", 8925.0, 6062.0, 2863.0, "Engineering", 0.320784, 55, 6170, 5455, 1983, 3413, 589, 0.087143, 57100, 40000, 76000, 3603, 1595, 524], [16, 17, 2412, "INDUSTRIAL AND MANUFACTURING ENGINEERING", 18968.0, 12453.0, 6515.0, "Engineering", 0.343473, 183, 15604, 14879, 2243, 11326, 699, 0.042876, 57000, 37900, 67000, 8306, 3235, 640], [17, 18, 2400, "GENERAL ENGINEERING", 61152.0, 45683.0, 15469.0, "Engineering", 0.25296, 425, 44931, 41235, 7199, 33540, 2859, 0.059824, 56000, 36000, 69000, 26898, 11734, 3192], [18, 19, 2403, "ARCHITECTURAL ENGINEERING", 2825.0, 1835.0, 990.0, "Engineering", 0.350442, 26, 2575, 2277, 343, 1848, 170, 0.061931, 54000, 38000, 65000, 1665, 649, 137], [20, 21, 2102, "COMPUTER SCIENCE", 128319.0, 99743.0, 28576.0, "Computers & Mathematics", 0.222695, 1196, 102087, 91485, 18726, 70932, 6884, 0.063173, 53000, 39000, 70000, 68622, 25667, 5144], [22, 23, 2502, "ELECTRICAL ENGINEERING TECHNOLOGY", 11565.0, 8181.0, 3384.0, "Engineering", 0.292607, 97, 8587, 7530, 1873, 5681, 824, 0.087557, 52000, 35000, 60000, 5126, 2686, 696], [23, 24, 2413, "MATERIALS ENGINEERING AND MATERIALS SCIENCE", 2993.0, 2020.0, 973.0, "Engineering", 0.325092, 22, 2449, 1658, 1040, 1151, 70, 0.027789, 52000, 3500

# %%
#
mask = (DF_raw['Women'])
DF_women=DF_raw[mask]
show(DF_women)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[219], line 3
#       1 #
#       2 mask = (DF_raw['Women'])
# ----> 3 DF_women=DF_raw[mask]
#       4 show(DF_women)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([  282.0,    77.0,   131.0,   135.0, 11021.0,   373.0,  1667.0,   960.0,\n       10907.0, 16016.0,\n       ...\n       37054.0, 36422.0,  7732.0, 28809.0, 11931.0,  5359.0,  2332.0,  2270.0,\n        3695.0,   964.0],\n      dtype='float64', length=173)] are in the [columns]"

# %%
#
DF_raw.groupby(by=['Median']).sum()
# Out:
#         Rank  Major_code                                              Major  \
# Median
# 22000    173        3501                                    LIBRARY SCIENCE
# 23400    172        5203                              COUNSELING PSYCHOLOGY
# 25000    341       10403          EDUCATIONAL PSYCHOLOGYCLINICAL PSYCHOLOGY
# 26000    169        3609                                            ZOOLOGY
# 27000    335        9303     DRAMA AND THEATER ARTSCOMPOSITION AND RHETORIC
# 27500    166        2603                            OTHER FOREIGN LANGUAGES
# 28000    492       13911  ANTHROPOLOGY AND ARCHEOLOGYCOMMUNICATION DISOR...
# 26000                              Biology & Life Science    0.637293
# 27000                       ArtsHumanities & Liberal Arts    1.295624
# 27500                           Humanities & Liberal Arts    0.690111
# 28000            Humanities & Liberal ArtsHealthEducation    2.644088
# 29000   Humanities & Liberal ArtsArtsIndustrial Arts &...    2.416964
# 30000   Industrial Arts & Consumer ServicesPsychology ...    6.525411
# 30500                                                Arts    0.667034
# 31000              ArtsEducationHumanities & Liberal Arts    1.797237
# 31500                            Psychology & Social Work    0.779933
# 32000   Humanities & Liberal ArtsEducationIndustrial A...    4.868194
# 32100                                           Education    0.686024
# 32200                           Humanities & Liberal Arts    0.416810
# 32400                                              Health    0.774577
# 32500                                           Education    0.601752
# 33000   Social ScienceCommunications & JournalismHealt...    6.216124
# 33400                              Biology & Life Science    0.601858
# 33500                        HealthBiology & Life Science    1.123244
# 34000   EducationHumanities & Liberal ArtsHumanities &...    5.326952
# 35000   Communications & JournalismLaw & Public Policy...   11.226227
# 35600                              Biology & Life Science    0.584556
# 36000   BusinessLaw & Public PolicyHealthLaw & Public ...    4.070499
# 36200                                   Physical Sciences    0.470197
# 36400                             Computers & Mathematics    0.305005
# 37000                              Biology & Life Science    0.528969
# 37400                              Biology & Life Science    0.515406
# 37500                             Computers & Mathematics    0.180883
# 38000   BusinessBusinessSocial ScienceSocial ScienceBi...    2.538695
# 38400                 Industrial Arts & Consumer Services    0.232444
# 39000                                   Physical Sciences    0.505141
# 40000   BusinessEngineeringBusinessHealthBiology & Lif...    6.938801
# 40100                                      Social Science    0.632987
# 41000                     Biology & Life ScienceEducation    1.419389
# 41300                             Computers & Mathematics    0.269194
# 42000                       HealthComputers & Mathematics    1.106789
# 44000                                         Engineering    0.174123
# 44700                                   Physical Sciences    0.688999
# 45000   BusinessComputers & MathematicsComputers & Mat...    4.174294
# 46000                BusinessEngineeringPhysical Sciences    1.430200
# 47000                              BusinessSocial Science    0.696294
# 48000                                              Health    0.896019
# 50000   EngineeringIndustrial Arts & Consumer Services...    2.717207
# 51000                                            Business    0.278790
# 52000                              EngineeringEngineering    0.617699
# 53000   Computers & MathematicsAgriculture & Natural R...    0.222695
# 54000                      EngineeringLaw & Public Policy    0.586505
# 56000                                         Engineering    0.252960
# 57000                                         Engineering    0.343473
# 57100                                         Engineering    0.320784
# 58000                                         Engineering    0.183985
# 60000   EngineeringEngineeringEngineeringEngineeringEn...    1.403882
# 62000                           BusinessPhysical Sciences    0.977070
# 65000                              EngineeringEngineering    0.486597
# 70000                                         Engineering    0.107313
# 73000                                         Engineering    0.153037
# 75000                                         Engineering    0.101852
# 110000                                        Engineering    0.120564
#
#         Sample_size  Employed  Full_time  Part_time  Full_time_year_round  \
# Median
# 22000             2       742        593        237                   410
# 23400            21      3777       3154        965                  2738
# 25000            20      4226       3572       1220                  2504
# 26000            47      6259       5043       2190                  3602
# 27000           508     51218      35268      22606                 24723
# 27500            56      7052       5197       3685                  3214
# 28000           684     91947      67691      35378                 48440
# 29000           633     48050      37290      16839                 28242
# 35600         1779           0.078585   25000   40200          8149
# 36000         3823           0.426460  158200  279000         12197
# 36200          677           0.075449   28000   47000          4858
# 36400         1100           0.151850   27000   49000          2593
# 37000            0           0.000000   26000   40000           677
# 37400         2249           0.080531   29000   50000         15654
# 37500          721           0.099723   25000   50000          2354
# 38000        50679           0.414843  146600  250000        109821
# 38400           64           0.029480   22500   45000           221
# 39000         2769           0.053972   30000   49900         30382
# 40000        27041           1.048569  505400  894000         83423
# 40100         2271           0.096799   31200   53000          6774
# 41000          311           0.182816   61000  103000          1878
# 41300          419           0.113983   20000   46000          2024
# 42000          407           0.042507   60000  143000          2543
# 44000           74           0.033652   30000   50000           482
# 44700           99           0.056995   23000   50000           459
# 45000        21548           0.619064  296200  520000         93509
# 46000         1431           0.196297  106000  176000          3134
# 47000        20865           0.159779   70000  129000         49825
# 48000         8497           0.044863   39000   58000        151643
# 50000         6889           0.694342  342800  554000         42501
# 51000         1015           0.058240   38000   60000          6342
# 52000          894           0.115346   70000  122000          7037
# 53000         7222           0.160104   71000  140000         69805
# 54000          181           0.073620   88000  119000          2067
# 56000         2859           0.059824   36000   69000         26898
# 57000          699           0.042876   37900   67000          8306
# 57100          589           0.087143   40000   76000          3603
# 58000           23           0.006334   25000   74000          2439
# 60000        12711           0.362214  255000  422000        139616
# 62000          341           0.116820   84500  181000          2740
# 65000         2072           0.238324  100000  177000         19456
# 70000           40           0.050125   43000   80000           529
# 73000           16           0.024096   50000  105000           456
# 75000           85           0.117241   55000   90000           350
# 110000          37           0.018381   95000  125000          1534
#
#         Non_college_jobs  Low_wage_jobs
# Median
# 22000                338            192
# 23400               1245            308
# 25000               1485            704
# 26000               2947            743
# 27000              33413          14534
# 27500               3703           1115
# 28000              33802          14859
# 29000              28754          10084
# 30000              65601          18794
# 30500              32725          11880
# 31000              47852          14754
# 31500             141860          48207
# 32000             231453          73191
# 32100               8260           2767
# 32200              20313           8051
# 32400              12889           3816
# 32500               3967           1385
# 33000             135175          41715
# 33400              81109          28339
# 33500               6261           1618
# 34000             129346          41274
# 35000             373996         101972
# 35600              10076           3175
# 36000              23415           5418
# 36200               2792            959
# 36400               2941            352
# 37000                184             56
# 37400               8394           3012
# 37500               3244            308
# 38000             319235          83317
# 38400               1659             81
# 39000              14718           4288
# 40000             164072          43338
# 40100               9570           2499
# 41000               1142            135
# 41300               1033            263
# 42000               7015           1295
# 44000                844            245
# 44700                996            186
# 45000              84270          21353
# 46000               8541           1888
# 47000              85504          20563
# 48000              26146           6193
# 50000              26496           5798
# 51000               5741            708
# 52000               2991            766
# 53000              26941           5629
# 54000               1177            281
# 56000              11734           3192
# 57000               3235            640
# 57100               1595            524
# 58000                947            263
# 60000              38266           8645
# 62000                814            479
# 65000               5097           1216
# 70000                102              0
# 73000                176              0
# 75000                257             50
# 110000               364            193

# %% [markdown]
# **(Click Here to Explain your Results)**

# %% [markdown]
# ### 4. Ask a question of interest to you.

# %%
#

# %% [markdown]
# **(Click Here to Explain your Results)**
